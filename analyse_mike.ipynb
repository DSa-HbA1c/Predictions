# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Complete-dataset-FINAL.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4684 entries, 0 to 4683
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Method name          4684 non-null   object
#  1   N (no. labs)         4684 non-null   object
#  2   Mean                 4602 non-null   float64
#  3   Bias                 4058 non-null   float64
#  4   CV                   4584 non-null   float64
#  5   Sample               4684 non-null   object
#  6   Reference Value      4656 non-null   float64
#  7   Year                 4684 non-null   int64
#  8   Source (CAP/EurA1c)  4684 non-null   object
#  9   Type (Fresh/frozen)  4684 non-null   object
#  10  Manufacturer         4684 non-null   object
#  11  Total Error          4684 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 439.2+ KB

# %%
df.head()
# Out:
#                  Method name N (no. labs)  Mean  Bias   CV  Sample  \
# 0  Vitros 5.1 FS. 4600. 5600          183  6.14 -0.16  2.3  GH2-04
# 1  Vitros 5.1 FS. 4600. 5600          183  7.59 -0.01  2.5  GH2-05
# 2  Vitros 5.1 FS. 4600. 5600          183  9.42  0.22  3.0  GH2-06
# 3  Vitros 5.1 FS. 4600. 5600          210  5.42 -0.18  2.3  GH2-01
# 4  Vitros 5.1 FS. 4600. 5600          210  9.34 -0.06  2.6  GH2-02
#
#    Reference Value  Year Source (CAP/EurA1c) Type (Fresh/frozen) Manufacturer  \
# 0              6.3  2011                 CAP               Fresh       Vitros
# 1              7.6  2011                 CAP               Fresh       Vitros
# 2              9.2  2011                 CAP               Fresh       Vitros
# 3              5.6  2012                 CAP               Fresh       Vitros
# 4              9.4  2012                 CAP               Fresh       Vitros
#
#    Total Error
# 0        4.348
# 1        4.890
# 2        6.100
# 3        4.328
# 4        5.036

# %%
# Groupby Method name
manufacturer = df.dropna().groupby('Manufacturer')
# order manufacturer by size
manufacturerSizes = manufacturer.size().sort_values(ascending=False)
# Only show top more then 100 size
manufacturerSizes = manufacturerSizes[manufacturerSizes > 100]
# Make a new dataframe with the top manufacturers from df
df_manufacturer = df[df['Manufacturer'].isin(manufacturerSizes.index)]
df_manufacturer
# Out:
#                                        Method name N (no. labs)  Mean  Bias  \
# 0                        Vitros 5.1 FS. 4600. 5600          183  6.14 -0.16
# 1                        Vitros 5.1 FS. 4600. 5600          183  7.59 -0.01
# 2                        Vitros 5.1 FS. 4600. 5600          183  9.42  0.22
# 3                        Vitros 5.1 FS. 4600. 5600          210  5.42 -0.18
# 4                        Vitros 5.1 FS. 4600. 5600          210  9.34 -0.06
# ...                                            ...          ...   ...   ...
# 4679  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  9.08  0.22
# 4680  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  6.86  0.02
# 4681  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  9.40  0.01
# 4682  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  6.14  0.01
# 4683  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  7.59  0.07
#
#        CV  Sample  Reference Value  Year Source (CAP/EurA1c)  \
# 0     2.3  GH2-04             6.30  2011                 CAP
# 1     2.5  GH2-05             7.60  2011                 CAP
# 2     3.0  GH2-06             9.20  2011                 CAP
# 3     2.3  GH2-01             5.60  2012                 CAP
# 4     2.6  GH2-02             9.40  2012                 CAP
# ...   ...     ...              ...   ...                 ...
# 4679  3.1  GH5-01             8.86  2021                 CAP
# 4680  2.6  GH5-02             6.84  2021                 CAP
# 4681  3.4  GH5-03             9.39  2021                 CAP
# 4682  2.5  GH5-04             6.13  2021                 CAP
# 4683  2.8  GH5-05             7.52  2021                 CAP
#
#      Type (Fresh/frozen) Manufacturer  Total Error
# 0                  Fresh       Vitros        4.348
# 1                  Fresh       Vitros        4.890
# 2                  Fresh       Vitros        6.100
# 3                  Fresh       Vitros        4.328
# 4                  Fresh       Vitros        5.036
# ...                  ...          ...          ...
# 4679               Fresh       Vitros        6.296
# 4680               Fresh       Vitros        5.116
# 4681               Fresh       Vitros        6.674
# 4682               Fresh       Vitros        4.910
# 4683               Fresh       Vitros        5.558
#
# [4172 rows x 12 columns]

# %%
manufacturerGroups = df_manufacturer.groupby('Manufacturer')
# loop manufacturerGroups
for name, data in manufacturerGroups:
    # line plot for Total Error with seaborn
    # if name == "Abbott":
        sns.set(rc = {'figure.figsize':(25,8)})
        l = sns.lineplot(x='Year', y='Total Error', data=data)
        l.set_title(name)
        plt.show()

# %%
for name, data in manufacturerGroups:
    tempdf = data[['Year', 'Total Error']].dropna()

    X = tempdf.iloc[:, :-1].values
    Y = tempdf.iloc[:, 1].values

    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

    from sklearn.linear_model import LinearRegression
    regressor = LinearRegression()
    regressor.fit(X_train, y_train)

    y_pred = regressor.predict(X_test)

    preddf = pd.DataFrame(y_pred, columns=['Total Error'])
    preddf['Year'] = "2022"

    print(y_pred)

    # Add tempdf and preddf together and reset index
    tempdf = pd.concat([tempdf, preddf], axis=0, ignore_index=True)

    # Set the correct type 
    tempdf = tempdf.astype({'Year': 'int32'})

    sns.set(rc = {'figure.figsize':(25,8)})
    l = sns.lineplot(x='Year', y='Total Error', data=tempdf)
    l.set_title(name)
    sns.lineplot(x='Year', y='Total Error', data=tempdf[(tempdf['Year'] >= 2021) & (tempdf['Year'] <= 2022)], color='orange')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Windesheim\4e semester\Project\Predictions\analyse_mike.ipynb Cell 6' in <cell line: 1>()
#      <a href='vscode-notebook-cell:/d%3A/Windesheim/4e%20semester/Project/Predictions/analyse_mike.ipynb#ch0000005?line=15'>16</a> preddf = pd.DataFrame(y_pred, columns=['Total Error'])
#      <a href='vscode-notebook-cell:/d%3A/Windesheim/4e%20semester/Project/Predictions/analyse_mike.ipynb#ch0000005?line=16'>17</a> preddf['Year'] = "2022"
# ---> <a href='vscode-notebook-cell:/d%3A/Windesheim/4e%20semester/Project/Predictions/analyse_mike.ipynb#ch0000005?line=18'>19</a> print(y_pred.summary())
#      <a href='vscode-notebook-cell:/d%3A/Windesheim/4e%20semester/Project/Predictions/analyse_mike.ipynb#ch0000005?line=20'>21</a> # Add tempdf and preddf together and reset index
#      <a href='vscode-notebook-cell:/d%3A/Windesheim/4e%20semester/Project/Predictions/analyse_mike.ipynb#ch0000005?line=21'>22</a> tempdf = pd.concat([tempdf, preddf], axis=0, ignore_index=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'summary'
